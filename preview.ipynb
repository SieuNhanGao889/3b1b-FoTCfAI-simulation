# %%
! manim -p -ql -n 7,17 scenes/scene_1a_point_to_block.py
# Out:
# Manim Community v0.20.1
#
# [04/28/26 15:12:25] INFO     Animation 7 : Using cached    cairo_renderer.py:94
#                              data (hash :
#                              4072820271_4217992463_3307253
#                              862)
# [04/28/26 15:12:27] INFO     Animation 8 : Using cached    cairo_renderer.py:94
#                              data (hash :
#                              4072820271_1584165909_1631721
#                              935)
# [04/28/26 15:12:29] INFO     Animation 9 : Using cached    cairo_renderer.py:94
#                              data (hash :
#                              4072820271_1782301063_6451535
#                              53)
# [04/28/26 15:12:30] INFO     Animation 10 : Using cached   cairo_renderer.py:94
#                              data (hash :
#                              4072820271_2195887995_6939135
#                              89)
# [04/28/26 15:12:32] INFO     Animation 11 : Using cached   cairo_renderer.py:94
# ...
